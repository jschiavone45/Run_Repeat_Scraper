# %%
import numpy as np
import pandas as pd
import re
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
time = 'Feb 2019'

# %%
df1 = pd.read_csv('running_shoes.csv')

# %%
df3['retail_price'].count()
# Out:
# 391

# %%
df3['retail_price'].map(lambda s: s.strip('$'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-d632e6e2918e> in <module>
# ----> 1 df3['retail_price'].map(lambda s: s.strip('$'))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1152
#    1153         # mapper is a function
# -> 1154         new_values = map_f(values, mapper)
#    1155
#    1156         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-112-d632e6e2918e> in <lambda>(s)
# ...

# %%
df3.to_csv('running_shoes_combined', index=False)

# %%
group = df3.groupby('b')

# %%
df3['sale_price'].count()
# Out:
# 391

# %%
group.agg('mean')['retail_price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'retail_price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-d7ac3e85fefe> in <module>
# ...

# %%
for key, values in group:
    print(key) #this indicates the grouping
    print('-'*70)
    print(values) #this is a dataframe for that 
    print('\n')
# Out:
#  361 Degrees
# ----------------------------------------------------------------------
#                    product         brand  core_score  expert_score  reviews  \
# 1027   361 Degrees Kroozer   361 Degrees        81.0           NaN     24.0
# 1113                   NaN   361 Degrees         NaN          87.0      NaN
# 1145  361 Degrees Chaser 2   361 Degrees        89.0          92.0      6.0
#
#      retail_price       sale_price terrain arch_support    weight_men  \
# 1027          $40   $30 (save 25%)    Road      Neutral    Men: 10oz
# 1113         $110  $24 (save 100%)    Road      Neutral   Men: 9.8oz
# 1145         $100   $19 (save 81%)    Road      Neutral   Men: 8.2oz
#
#        weight_women heel_to_toe_men heel_to_toe_women release_date  \
# 1027    Women: 10oz       Men: 8mm         Women: 8mm          NaN
# 1113   Women: 8.2oz       Men: 8mm         Women: 8mm          NaN
# 1145   Women: 6.8oz       Men: 8mm         Women: 8mm          NaN
#
# ...
